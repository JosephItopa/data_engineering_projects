# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
# Downloading imdb top 250 movie's data
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
#print(soup.prettify())
#list(soup.children)
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
#html = list(soup.children)[3]
#list(html.children)
#body = list(html.children)[3]
#list(body.children)[3]
# Out:
# [<p>The Top Rated Movie list only includes feature films.</p>,
#  <p class="imdb-footer__copyright footer__copyright">© 1990-<!-- -->2022<!-- --> by IMDb.com, Inc.</p>]

# %%
#soup.find_all('p')
soup.select("div p")
# Out:
# [<p>The Top Rated Movie list only includes feature films.</p>,
#  <p class="imdb-footer__copyright footer__copyright">© 1990-<!-- -->2022<!-- --> by IMDb.com, Inc.</p>]

# %%
movies = soup.select('td.titleColumn')
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]

# %%
# create a empty list for storing
# movie information
list = []

# Iterating over movies to extract
# each movie's details
for index in range(0, len(movies)):
	
	# Separating movie into: 'place',
	# 'title', 'year'
	movie_string = movies[index].get_text()
	movie = (' '.join(movie_string.split()).replace('.', ''))
	movie_title = movie[len(str(index))+1:-7]
	year = re.search('\((.*?)\)', movie_string).group(1)
	place = movie[:len(str(index))-(len(movie))]
	data = {"place": place,
			"movie_title": movie_title,
			"rating": ratings[index],
			"year": year,
			"star_cast": crew[index],
			}
	list.append(data)

# %%
for movie in list:
	print(movie['place'], '-', movie['movie_title'], '('+movie['year'] +
		') -', 'Starring:', movie['star_cast'], movie['rating'])
# Out:
# 1 - The Shawshank Redemption (1994) - Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman 9.235228911762258
# 2 - The Godfather (1972) - Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino 9.156085111265273
# 3 - The Dark Knight (2008) - Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger 8.989211634325583
# 4 - The Godfather Part II (1974) - Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro 8.984088961727375
# 5 - 12 Angry Men (1957) - Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb 8.95075650853193
# 6 - Schindler's List (1993) - Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes 8.937953929199402
# 7 - The Lord of the Rings: The Return of the King (2003) - Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen 8.928577087867515
# 8 - Pulp Fiction (1994) - Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman 8.848453178833672
# 9 - The Lord of the Rings: The Fellowship of the Ring (2001) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen 8.808643684100197
# 1 -  Il buono, il brutto, il cattivo (1966) - Starring: Sergio Leone (dir.), Clint Eastwood, Eli Wallach 8.79106395468745
# 11 - Forrest Gump (1994) - Starring: Robert Zemeckis (dir.), Tom Hanks, Robin Wright 8.767645153282269
# 12 - Fight Club (1999) - Starring: David Fincher (dir.), Brad Pitt, Edward Norton 8.748761515402494
# 13 - The Lord of the Rings: The Two Towers (2002) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen 8.733815958133682
# 14 - Inception (2010) - Starring: Christopher Nolan (dir.), Leonardo DiCaprio, Joseph Gordon-Levitt 8.733220189552023
# 15 - The Empire Strikes Back (1980) - Starring: Irvin Kershner (dir.), Mark Hamill, Harrison Ford 8.700093023107145
# 16 - The Matrix (1999) - Starring: Lana Wachowski (dir.), Keanu Reeves, Laurence Fishbur
ingmar Bergman (dir.), Bibi Andersson, Liv Ullmann 8.012786052413507
# 245 - Life of Brian (1979) - Starring: Terry Jones (dir.), Graham Chapman, John Cleese 8.011839570476415
# 246 - Dersu Uzala (1975) - Starring: Akira Kurosawa (dir.), Maksim Munzuk, Yuriy Solomin 8.008262166276184
# 247 - Aladdin (1992) - Starring: Ron Clements (dir.), Scott Weinger, Robin Williams 8.005179400099054
# 248 - The Help (2011) - Starring: Tate Taylor (dir.), Viola Davis, Emma Stone 8.004898237026714
# 249 - The Iron Giant (1999) - Starring: Brad Bird (dir.), Eli Marienthal, Harry Connick Jr. 8.004557600577945
# 250 - Gandhi (1982) - Starring: Richard Attenborough (dir.), Ben Kingsley, John Gielgud 8.004363897124804

# %%
#saving the list as dataframe
#then converting into .csv file
df = pd.DataFrame(list)
df.head()
# Out:
#   place               movie_title             rating  year  \
# 0     1  The Shawshank Redemption  9.235228911762258  1994
# 1     2             The Godfather  9.156085111265273  1972
# 2     3           The Dark Knight  8.989211634325583  2008
# 3     4     The Godfather Part II  8.984088961727375  1974
# 4     5              12 Angry Men   8.95075650853193  1957
#
#                                            star_cast
# 0  Frank Darabont (dir.), Tim Robbins, Morgan Fre...
# 1  Francis Ford Coppola (dir.), Marlon Brando, Al...
# 2  Christopher Nolan (dir.), Christian Bale, Heat...
# 3  Francis Ford Coppola (dir.), Al Pacino, Robert...
# 4      Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb

# %%
df.to_csv('imdb_top_250_movies.csv',index = False)

# %%
"""
genres = [
    "Adventure",
    "Comedy",
    "Crime",
    "Drama",
    "Family",
    "Fantasy",
    "Horror",
    "Musical",
    "Mystery",
    "Romance",
    "Sci-Fi",
    "Sport",
    "Thriller"
]

url_dict = {}

for genre in genres:
    url = "https://www.imdb.com/search/title/?genres={}&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16"
    formated_url = url.format(genre)
    url_dict[genre] = formated_url
    
print(url_dict)
"""
# Out:
# {'Adventure': 'https://www.imdb.com/search/title/?genres=Adventure&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Comedy': 'https://www.imdb.com/search/title/?genres=Comedy&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Crime': 'https://www.imdb.com/search/title/?genres=Crime&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Drama': 'https://www.imdb.com/search/title/?genres=Drama&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Family': 'https://www.imdb.com/search/title/?genres=Family&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Fantasy': 'https://www.imdb.com/search/title/?genres=Fantasy&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Horror': 'https://www.imdb.com/search/title/?genres=Horror&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Musical': 'https://www.imdb.com/search/title/?genres=Musical&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Mystery': 'https://www.imdb.com/search/title/?genres=Mystery&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Romance': 'https://www.imdb.com/search/title/?genres=Romance&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Sci-Fi': 'https://www.imdb.com/search/title/?genres=Sci-Fi&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Sport': 'https://www.imdb.com/search/title/?genres=Sport&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'Thriller': 'https://www.imdb.com/search/title/?genres=Thriller&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16'}

# %%
HEADERS ={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
url = "https://www.imdb.com/search/title/?genres=Adventure&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16"

# Sending a request to the speciifed URL
resp = requests.get(url, headers=HEADERS)

# Converting the response to Beautiful Soup Object
content = BeautifulSoup(resp.content, 'lxml')

# Iterating throught the list of movies 
for movie in content.select('.lister-item-content'):
        
    try:
        # Creating a python dictonary
        data = {
            
            "title":movie.select('.lister-item-header')[0].get_text().strip(),
            "year":movie.select('.lister-item-year')[0].get_text().strip(),
            "certificate":movie.select('.certificate')[0].get_text().strip(),
            "time":movie.select('.runtime')[0].get_text().strip(),
            "genre":movie.select('.genre')[0].get_text().strip(),
            "rating":movie.select('.ratings-imdb-rating')[0].get_text().strip(),
            "metascore":movie.select('.ratings-metascore')[0].get_text().strip(),
            "simple_desc":movie.select('.text-muted')[2].get_text().strip(),
            "votes":movie.select('.sort-num_votes-visible')[0].get_text().strip()                
        }
    except IndexError:
        continue
        
    print(data)
# Out:
# {'title': '2.\nThe Lord of the Rings: The Return of the King\n(2003)', 'year': '(2003)', 'certificate': 'PG', 'time': '201 min', 'genre': 'Action, Adventure, Drama', 'rating': '9.0', 'metascore': '94        \n        Metascore', 'simple_desc': "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.", 'votes': 'Votes:\n1,836,623\n| Gross:\n$377.85M'}
# {'title': '4.\nInception\n(2010)', 'year': '(2010)', 'certificate': 'PG-13', 'time': '148 min', 'genre': 'Action, Adventure, Sci-Fi', 'rating': '8.8', 'metascore': '74        \n        Metascore', 'simple_desc': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.', 'votes': 'Votes:\n2,336,649\n| Gross:\n$292.58M'}
# {'title': '5.\nThe Lord of the Rings: The Two Towers\n(2002)', 'year': '(2002)', 'certificate': 'PG', 'time': '179 min', 'genre': 'Action, Adventure, Drama', 'rating': '8.8', 'metascore': '87        \n        Metascore', 'simple_desc': "While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.", 'votes': 'Votes:\n1,658,409\n| Gross:\n$342.55M'}
# {'title': '6.\nThe Lord of the Rings: The Fellowship of the Ring\n(2001)', 'year': '(2001)', 'certificate': 'PG', 'time': '178 min', 'genre': 'Action, Adventure, Drama', 'rating': '8.8', 'metascore': '92        \n        Metascore', 'simple_desc': 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.', 'votes': 'Votes:\n1,865,692\n| Gross:\n$315.54M'}
# {'title': '8.\nThe Empire Strikes Back\n(1980)', 'year': '(1980)', 'certificate': 'PG', 'time': '124 min', 'genre': 'Action, Adventure, Fantasy', 'rating': '8.7', 'metascore': '82        \n        Metascore', 'simple_desc': 'After the Rebels are brutally overpowered by the Empire on the ice planet Hoth, Luke Skywalker begins Jedi training with Yoda, while his friends are pursued across the galaxy by Darth Vader and bounty hunter Boba Fett.', 'votes': 'Votes:\n1,286,469\n| Gross:\n$290.48M'}
# {'title': '9.\nInterstellar\n(2014)', 'year': '(2014)', 'certificate': 'G', 'time': '169 min', 'genre': 'Adventure, Drama, Sci-Fi', 'rating': '8.6', 'metascore': '74        \n        Metascore', 'simple_desc': "A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.", 'votes': 'Votes:\n1,810,507\n| Gross:\n$188.02M'}
# {'title': '10.\nSen to Chihiro no kamikakushi\n(2001)', 'year': '(2001)', 'certificate': 'G', 'time': '125 min', 'genre': 'Animation, Adventure, Family', 'rating': '8.6', 'metascore': '96        \n        Metascore', 'simple_desc': "During her family's move to the suburbs, a sullen 10-year-old girl wanders into a world ruled by gods, witches, and spirits, and where humans are changed into beasts.", 'votes': 'Votes:\n759,048\n| Gross:\n$10.06M'}
# {'title': '11.\nStar Wars\n(1977)', 'year': '(1977)', 'certificate': 'G', 'time': '121 min', 'genre': 'Action, Adventure, Fantasy', 'rating': '8.6', 'metascore': '90        \n        Metascore', 'simple_desc': "Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a Wookiee and two droids to save the galaxy from the Empire's world-destroying battle station, while also attempting to rescue Princess Leia from the mysterious Darth Vader.", 'votes': 'Votes:\n1,359,038\n| Gross:\n$322.74M'}
# {'title': '13.\nGladiator\n(2000)', 'year': '(2000)', 'certificate': 'R', 'time': '155 min', 'genre': 'Action, Adventure, Drama', 'rating': '8.5', 'metascore': '67        \n        Metascore', 'simple_desc': 'A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.', 'votes': 'Votes:\n1,492,869\n| Gross:\n$187.71M'}
# {'title': '14.\nThe Lion King\n(1994)', 'year': '(1994)', 'certificate': 'G', 'time': '88 min', 'genre': 'Animation, Adventure, Drama', 'rating': '8.5', 'metascore': '88        \n        Metascore', 'simple_desc': 'Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.', 'votes': 'Votes:\n1,053,321\n| Gross:\n$422.78M'}
# {'title': '16.\nSpider-Man: Into the Spider-Verse\n(2018)', 'year': '(2018)', 'certificate': 'PG', 'time': '117 min', 'genre': 'Animation, Action, Adventure', 'rating': '8.4', 'metascore': '87        \n        Metascore', 'simple_desc': 'Teen Miles Morales becomes the Spider-Man of his universe, and must join with five spider-powered individuals from other dimensions to stop a threat for all realities.', 'votes': 'Votes:\n523,808\n| Gross:\n$190.24M'}
# {'title': '17.\nAvengers: Endgame\n(2019)', 'year': '(2019)', 'certificate': '12A', 'time': '181 min', 'genre': 'Action, Adventure, Drama', 'rating': '8.4', 'metascore': '78        \n        Metascore', 'simple_desc': "After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.", 'votes': 'Votes:\n1,119,296\n| Gross:\n$858.37M'}
# {'title': '18.\nAvengers: Infinity War\n(2018)', 'year': '(2018)', 'certificate': '12A', 'time': '149 min', 'genre': 'Action, Adventure, Sci-Fi', 'rating': '8.4', 'metascore': '68        \n        Metascore', 'simple_desc': 'The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.', 'votes': 'Votes:\n1,071,615\n| Gross:\n$678.82M'}
# {'title': '19.\nCoco\n(I) (2017)', 'year': '(I) (2017)', 'certificate': 'G', 'time': '105 min', 'genre': 'Animation, Adventure, Comedy', 'rating': '8.4', 'metascore': '81        \n        Metascore', 'simple_desc': "Aspiring musician Miguel, confronted with his family's ancestral ban on music, enters the Land of the Dead to find his great-great-grandfather, a legendary singer.", 'votes': 'Votes:\n504,239\n| Gross:\n$209.73M'}
# {'title': '21.\nMononoke-hime\n(1997)', 'year': '(1997)', 'certificate': 'PG', 'time': '134 min', 'genre': 'Animation, Action, Adventure', 'rating': '8.4', 'metascore': '76        \n        Metascore', 'simple_desc': "On a journey to find the cure for a Tatarigami's curse, Ashitaka finds himself in the middle of a war between the forest gods and Tatara, a mining colony. In this quest he also meets San, the Mononoke Hime.", 'votes': 'Votes:\n393,999\n| Gross:\n$2.38M'}
# {'title': '22.\nAliens\n(1986)', 'year': '(1986)', 'certificate': '15', 'time': '137 min', 'genre': 'Action, Adventure, Sci-Fi', 'rating': '8.4', 'metascore': '84        \n        Metascore', 'simple_desc': 'Fifty-seven years after surviving an apocalyptic attack aboard her space vessel by merciless space creatures, Officer Ripley awakens from hyper-sleep and tries to warn anyone who will listen about the predators.', 'votes': 'Votes:\n716,118\n| Gross:\n$85.16M'}
# {'title': '23.\nRaiders of the Lost Ark\n(1981)', 'year': '(1981)', 'certificate': 'G', 'time': '115 min', 'genre': 'Action, Adventure', 'rating': '8.4', 'metascore': '85        \n        Metascore', 'simple_desc': 'Archaeology professor Indiana Jones ventures to seize a biblical artefact known as the Ark of the Covenant. While doing so, he puts up a fight against Renee and a troop of Nazis.', 'votes': 'Votes:\n962,698\n| Gross:\n$248.16M'}
# {'title': '24.\nSpider-Man: No Way Home\n(2021)', 'year': '(2021)', 'certificate': 'PG-13', 'time': '148 min', 'genre': 'Action, Adventure, Fantasy', 'rating': '8.3', 'metascore': '71        \n        Metascore', 'simple_desc': "With Spider-Man's identity now revealed, Peter asks Doctor Strange for help. When a spell goes wrong, dangerous foes from other worlds start to appear, forcing Peter to discover what it truly means to be Spider-Man.", 'votes': 'Votes:\n745,274\n| Gross:\n$804.75M'}
# {'title': '25.\nUp\n(2009)', 'year': '(2009)', 'certificate': 'PG', 'time': '96 min', 'genre': 'Animation, Adventure, Comedy', 'rating': '8.3', 'metascore': '88        \n        Metascore', 'simple_desc': '78-year-old Carl Fredricksen travels to Paradise Falls in his house equipped with balloons, inadvertently taking a young stowaway.', 'votes': 'Votes:\n1,040,146\n| Gross:\n$293.00M'}
# {'title': '27.\nInglourious Basterds\n(2009)', 'year': '(2009)', 'certificate': 'R', 'time': '153 min', 'genre': 'Adventure, Drama, War', 'rating': '8.3', 'metascore': '69        \n        Metascore', 'simple_desc': "In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.", 'votes': 'Votes:\n1,440,003\n| Gross:\n$120.54M'}
# {'title': '28.\nToy Story\n(1995)', 'year': '(1995)', 'certificate': 'G', 'time': '81 min', 'genre': 'Animation, Adventure, Comedy', 'rating': '8.3', 'metascore': '95        \n        Metascore', 'simple_desc': "A cowboy doll is profoundly threatened and jealous when a new spaceman action figure supplants him as top toy in a boy's bedroom.", 'votes': 'Votes:\n990,166\n| Gross:\n$191.80M'}
# {'title': '29.\nStar Wars: Episode VI - Return of the Jedi\n(1983)', 'year': '(1983)', 'certificate': 'G', 'time': '131 min', 'genre': 'Action, Adventure, Fantasy', 'rating': '8.3', 'metascore': '58        \n        Metascore', 'simple_desc': "After a daring mission to rescue Han Solo from Jabba the Hutt, the Rebels dispatch to Endor to destroy the second Death Star. Meanwhile, Luke struggles to help Darth Vader back from the dark side without falling into the Emperor's trap.", 'votes': 'Votes:\n1,050,087\n| Gross:\n$309.13M'}
# {'title': '32.\nNorth by Northwest\n(1959)', 'year': '(1959)', 'certificate': 'G', 'time': '136 min', 'genre': 'Action, Adventure, Mystery', 'rating': '8.3', 'metascore': '98        \n        Metascore', 'simple_desc': 'A New York City advertising executive goes on the run after being mistaken for a government agent by a group of foreign spies, and falls for a woman whose loyalties he begins to doubt.', 'votes': 'Votes:\n328,290\n| Gross:\n$13.28M'}
# {'title': '33.\nInside Out\n(I) (2015)', 'year': '(I) (2015)', 'certificate': 'PG', 'time': '95 min', 'genre': 'Animation, Adventure, Comedy', 'rating': '8.2', 'metascore': '94        \n        Metascore', 'simple_desc': 'After young Riley is uprooted from her Midwest life and moved to San Francisco, her emotions - Joy, Fear, Anger, Disgust and Sadness - conflict on how best to navigate a new city, house, and school.', 'votes': 'Votes:\n710,920\n| Gross:\n$356.46M'}
# {'title': '34.\nKimetsu no Yaiba: Mugen Ressha-Hen\n(2020)', 'year': '(2020)', 'certificate': 'R', 'time': '117 min', 'genre': 'Animation, Action, Adventure', 'rating': '8.2', 'metascore': '72        \n        Metascore', 'simple_desc': "After his family was brutally murdered and his sister turned into a demon, Tanjiro Kamado's journey as a demon slayer began. Tanjiro and his comrades embark on a new mission aboard the Mugen Train, on track to despair.", 'votes': 'Votes:\n57,973\n| Gross:\n$47.70M'}
# {'title': '35.\nHauru no ugoku shiro\n(2004)', 'year': '(2004)', 'certificate': 'PG', 'time': '119 min', 'genre': 'Animation, Adventure, Family', 'rating': '8.2', 'metascore': '80        \n        Metascore', 'simple_desc': 'When an unconfident young woman is cursed with an old body by a spiteful witch, her only chance of breaking the spell lies with a self-indulgent yet insecure young wizard and his companions in his legged, walking castle.', 'votes': 'Votes:\n394,464\n| Gross:\n$4.71M'}
# {'title': '37.\nJurassic Park\n(1993)', 'year': '(1993)', 'certificate': 'PG', 'time': '127 min', 'genre': 'Action, Adventure, Sci-Fi', 'rating': '8.2', 'metascore': '68        \n        Metascore', 'simple_desc': "A pragmatic paleontologist touring an almost complete theme park on an island in Central America is tasked with protecting a couple of kids after a power failure causes the park's cloned dinosaurs to run loose.", 'votes': 'Votes:\n985,046\n| Gross:\n$402.45M'}
# {'title': '38.\nIndiana Jones and the Last Crusade\n(1989)', 'year': '(1989)', 'certificate': 'G', 'time': '127 min', 'genre': 'Action, Adventure', 'rating': '8.2', 'metascore': '65        \n        Metascore', 'simple_desc': 'In 1938, after his father Professor Henry Jones, Sr. goes missing while pursuing the Holy Grail, Professor Henry "Indiana" Jones, Jr. finds himself up against Adolf Hitler\'s Nazis again to stop them from obtaining its powers.', 'votes': 'Votes:\n753,018\n| Gross:\n$197.17M'}
# {'title': '42.\nThe Bridge on the River Kwai\n(1957)', 'year': '(1957)', 'certificate': 'PG', 'time': '161 min', 'genre': 'Adventure, Drama, War', 'rating': '8.2', 'metascore': '87        \n        Metascore', 'simple_desc': 'British POWs are forced to build a railway bridge across the river Kwai for their Japanese captors in occupied Burma, not knowing that the allied forces are planning a daring commando raid through the jungle to destroy it.', 'votes': 'Votes:\n221,376\n| Gross:\n$44.91M'}
# {'title': '47.\nEverything Everywhere All at Once\n(2022)', 'year': '(2022)', 'certificate': 'R', 'time': '139 min', 'genre': 'Action, Adventure, Comedy', 'rating': '8.1', 'metascore': '81        \n        Metascore', 'simple_desc': 'An aging Chinese immigrant is swept up in an insane adventure, in which she alone can save the world by exploring other universes connecting with the lives she could have led.', 'votes': 'Votes:\n239,452'}
# {'title': '48.\nKlaus\n(2019)', 'year': '(2019)', 'certificate': 'PG', 'time': '96 min', 'genre': 'Animation, Adventure, Comedy', 'rating': '8.1', 'metascore': '65        \n        Metascore', 'simple_desc': "A simple act of kindness always sparks another, even in a frozen, faraway place. When Smeerensburg's new postman, Jesper, befriends toymaker Klaus, their gifts melt an age-old feud and deliver a sleigh full of holiday traditions.", 'votes': 'Votes:\n149,295'}

# %% [markdown]
# ### Extract

# %%
import time

def get_movies(url, interval, file_name):
    HEADERS ={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
    resp = requests.get(url, headers=HEADERS)
    content = BeautifulSoup(resp.content, 'lxml')

    movie_list = []

    for movie in content.select('.lister-item-content'):
        time.sleep(interval)
        try:
            data = {
                "title":movie.select('.lister-item-header')[0].get_text().strip(),
                "year":movie.select('.lister-item-year')[0].get_text().strip(),
                "certificate":movie.select('.certificate')[0].get_text().strip(),
                "time":movie.select('.runtime')[0].get_text().strip(),
                "genre":movie.select('.genre')[0].get_text().strip(),
                "rating":movie.select('.ratings-imdb-rating')[0].get_text().strip(),
                "metascore":movie.select('.ratings-metascore')[0].get_text().strip(),
                "simple_desc":movie.select('.text-muted')[2].get_text().strip(),
                "votes":movie.select('.sort-num_votes-visible')[0].get_text().strip()
                
            }
        except IndexError:
            continue
    
        movie_list.append(data)
         
        
    dataframe = pd.DataFrame(movie_list)
    dataframe.to_csv(file_name, index = False)

# Calling the function
#get_movies(url, 0, 'Adventure_movies.csv')

# %%
url = "https://www.imdb.com/search/title/?genres=Adventure&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16"
genres = [
    "adventure",
    "crime",
    "horror",
    "mystery",
    "sci-fi",
    "thriller"
]
url_dict = {}
for genre in genres:
    #url = "https://www.imdb.com/search/title/?genres={}&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16"
    formated_url = url.format(genre)
    url_dict[genre] = formated_url
    
print(url_dict)
# Out:
# {'adventure': 'https://www.imdb.com/search/title/?genres=Adventure&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'crime': 'https://www.imdb.com/search/title/?genres=Adventure&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'horror': 'https://www.imdb.com/search/title/?genres=Adventure&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'mystery': 'https://www.imdb.com/search/title/?genres=Adventure&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'sci-fi': 'https://www.imdb.com/search/title/?genres=Adventure&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16', 'thriller': 'https://www.imdb.com/search/title/?genres=Adventure&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=5aab685f-35eb-40f3-95f7-c53f09d542c3&pf_rd_r=N97GEQS6R7J9EV7V770D&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_16'}

# %%
for genre, url in url_dict.items():
    get_movies(url, 1, genre+'.csv')
    print("Saved:", genre+'.csv')
# Out:
# Saved: adventure.csv
# Saved: crime.csv
# Saved: horror.csv
# Saved: mystery.csv
# Saved: sci-fi.csv
# Saved: thriller.csv

# %%
##https://www.pycodemates.com/2022/02/scrape-movie-information-from-imdb-using-python-and-bs4.html
#ACCESS_KEY='AKIAVCI2VIMCOV4GR4FV'  
#SECRET_KEY='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'
#s3=boto3.client('s3',aws_access_key_id=ACCESS_KEY,aws_secret_access_key=SECRET_KEY)

# %% [markdown]
# ### Transform

# %%
df_advent, df_crime, df_horror, df_mystery, df_sci, df_thriller = pd.read_csv('adventure.csv'), pd.read_csv('crime.csv'), pd.read_csv('horror.csv'), pd.read_csv('mystery.csv'), pd.read_csv('sci-fi.csv'), pd.read_csv('thriller.csv')

# %%
df_advent['genre'], df_crime['genre'], df_horror['genre'],df_mystery['genre'], df_sci['genre'], df_thriller['genre'] = 'adventure', 'crime', 'horror', 'mystery', 'scifi', 'thriller'
df_thriller
# Out:
#                                                 title        year certificate  \
# 0   2.\nThe Lord of the Rings: The Return of the K...      (2003)          PG
# 1                               4.\nInception\n(2010)      (2010)       PG-13
# 2   5.\nThe Lord of the Rings: The Two Towers\n(2002)      (2002)          PG
# 3   6.\nThe Lord of the Rings: The Fellowship of t...      (2001)          PG
# 4                 8.\nThe Empire Strikes Back\n(1980)      (1980)          PG
# 5                            9.\nInterstellar\n(2014)      (2014)           G
# 6          10.\nSen to Chihiro no kamikakushi\n(2001)      (2001)           G
# 7                              11.\nStar Wars\n(1977)      (1977)           G
# 8                              13.\nGladiator\n(2000)      (2000)           R
# 9                          14.\nThe Lion King\n(1994)      (1994)           G
# 10     16.\nSpider-Man: Into the Spider-Verse\n(2018)      (2018)          PG
# 11                     17.\nAvengers: Endgame\n(2019)      (2019)         12A
# 12                18.\nAvengers: Infinity War\n(2018)      (2018)         12A
# 13                              19.\nCoco\n(I) (2017)  (I) (2017)           G
# 14                         21.\nMononoke-hime\n(1997)      (1997)          PG
# 15                                22.\nAliens\n(1986)      (1986)          15
# 16               23.\nRaiders of the Lost Ark\n(1981)      (1981)           G
# 17               24.\nSpider-Man: No Way Home\n(2021)      (2021)       PG-13
# 18                                    25.\nUp\n(2009)      (2009)          PG
# 19                  27.\nInglourious Basterds\n(2009)      (2009)           R
# 20                             28.\nToy Story\n(1995)      (1995)           G
# 21  29.\nStar Wars: Episode VI - Return of the Jed...      (1983)           G
# 22                    32.\nNorth by Northwest\n(1959)      (1959)           G
# 23                        33.\nInside Out\n(I) (2015)  (I) (2015)          PG
# 24    34.\nKimetsu no Yaiba: Mugen Ressha-Hen\n(2020)      (2020)           R
# 25                  35.\nHauru no ugoku shiro\n(2004)      (2004)          PG
# 26                         37.\nJurassic Park\n(1993)      (1993)          PG
# 27    38.\nIndiana Jones and the Last Crusade\n(1989)      (1989)           G
# 28          42.\nThe Bridge on the River Kwai\n(1957)      (1957)          PG
# 29     47.\nEverything Everywhere All at Once\n(2022)      (2022)           R
# 30                                 48.\nKlaus\n(2019)      (2019)          PG
#
#        time     genre  rating                      metascore  \
# 0   201 min  thriller     9.0  94        \n        Metascore
# 1   148 min  thriller     8.8  74        \n        Metascore
# 2   179 min  thriller     8.8  87        \n        Metascore
# 3   178 min  thriller     8.8  92        \n        Metascore
# 4   124 min  thriller     8.7  82        \n        Metascore
# 5   169 min  thriller     8.6  74        \n        Metascore
# 6   125 min  thriller     8.6  96        \n        Metascore
# 7   121 min  thriller     8.6  90        \n        Metascore
# 8   155 min  thriller     8.5  67        \n        Metascore
# 9    88 min  thriller     8.5  88        \n        Metascore
# 10  117 min  thriller     8.4  87        \n        Metascore
# 11  181 min  thriller     8.4  78        \n        Metascore
# 12  149 min  thriller     8.4  68        \n        Metascore
# 13  105 min  thriller     8.4  81        \n        Metascore
# 14  134 min  thriller     8.4  76        \n        Metascore
# 15  137 min  thriller     8.4  84        \n        Metascore
# 16  115 min  thriller     8.4  85        \n        Metascore
# 17  148 min  thriller     8.3  71        \n        Metascore
# 18   96 min  thriller     8.3  88        \n        Metascore
# 19  153 min  thriller     8.3  69        \n        Metascore
# 20   81 min  thriller     8.3  95        \n        Metascore
# 21  131 min  thriller     8.3  58        \n        Metascore
# 22  136 min  thriller     8.3  98        \n        Metascore
# 23   95 min  thriller     8.2  94        \n        Metascore
# 24  117 min  thriller     8.2  72        \n        Metascore
# 25  119 min  thriller     8.2  80        \n        Metascore
# 26  127 min  thriller     8.2  68        \n        Metascore
# 27  127 min  thriller     8.2  65        \n        Metascore
# 28  161 min  thriller     8.2  87        \n        Metascore
# 29  139 min  thriller     8.1  81        \n        Metascore
# 30   96 min  thriller     8.1  65        \n        Metascore
#
#                                           simple_desc  \
# 0   Gandalf and Aragorn lead the World of Men agai...
# 1   A thief who steals corporate secrets through t...
# 2   While Frodo and Sam edge closer to Mordor with...
# 3   A meek Hobbit from the Shire and eight compani...
# 4   After the Rebels are brutally overpowered by t...
# 5   A team of explorers travel through a wormhole ...
# 6   During her family's move to the suburbs, a sul...
# 7   Luke Skywalker joins forces with a Jedi Knight...
# 8   A former Roman General sets out to exact venge...
# 9   Lion prince Simba and his father are targeted ...
# 10  Teen Miles Morales becomes the Spider-Man of h...
# 11  After the devastating events of Avengers: Infi...
# 12  The Avengers and their allies must be willing ...
# 13  Aspiring musician Miguel, confronted with his ...
# 14  On a journey to find the cure for a Tatarigami...
# 15  Fifty-seven years after surviving an apocalypt...
# 16  Archaeology professor Indiana Jones ventures t...
# 17  With Spider-Man's identity now revealed, Peter...
# 18  78-year-old Carl Fredricksen travels to Paradi...
# 19  In Nazi-occupied France during World War II, a...
# 20  A cowboy doll is profoundly threatened and jea...
# 21  After a daring mission to rescue Han Solo from...
# 22  A New York City advertising executive goes on ...
# 23  After young Riley is uprooted from her Midwest...
# 24  After his family was brutally murdered and his...
# 25  When an unconfident young woman is cursed with...
# 26  A pragmatic paleontologist touring an almost c...
# 27  In 1938, after his father Professor Henry Jone...
# 28  British POWs are forced to build a railway bri...
# 29  An aging Chinese immigrant is swept up in an i...
# 30  A simple act of kindness always sparks another...
#
#                                     votes
# 0   Votes:\n1,836,623\n| Gross:\n$377.85M
# 1   Votes:\n2,336,649\n| Gross:\n$292.58M
# 2   Votes:\n1,658,409\n| Gross:\n$342.55M
# 3   Votes:\n1,865,692\n| Gross:\n$315.54M
# 4   Votes:\n1,286,469\n| Gross:\n$290.48M
# 5   Votes:\n1,810,507\n| Gross:\n$188.02M
# 6      Votes:\n759,048\n| Gross:\n$10.06M
# 7   Votes:\n1,359,038\n| Gross:\n$322.74M
# 8   Votes:\n1,492,869\n| Gross:\n$187.71M
# 9   Votes:\n1,053,321\n| Gross:\n$422.78M
# 10    Votes:\n523,808\n| Gross:\n$190.24M
# 11  Votes:\n1,119,296\n| Gross:\n$858.37M
# 12  Votes:\n1,071,615\n| Gross:\n$678.82M
# 13    Votes:\n504,239\n| Gross:\n$209.73M
# 14      Votes:\n393,999\n| Gross:\n$2.38M
# 15     Votes:\n716,118\n| Gross:\n$85.16M
# 16    Votes:\n962,698\n| Gross:\n$248.16M
# 17    Votes:\n745,274\n| Gross:\n$804.75M
# 18  Votes:\n1,040,146\n| Gross:\n$293.00M
# 19  Votes:\n1,440,003\n| Gross:\n$120.54M
# 20    Votes:\n990,166\n| Gross:\n$191.80M
# 21  Votes:\n1,050,087\n| Gross:\n$309.13M
# 22     Votes:\n328,290\n| Gross:\n$13.28M
# 23    Votes:\n710,920\n| Gross:\n$356.46M
# 24      Votes:\n57,973\n| Gross:\n$47.70M
# 25      Votes:\n394,464\n| Gross:\n$4.71M
# 26    Votes:\n985,046\n| Gross:\n$402.45M
# 27    Votes:\n753,018\n| Gross:\n$197.17M
# 28     Votes:\n221,376\n| Gross:\n$44.91M
# 29                        Votes:\n239,452
# 30                        Votes:\n149,295

# %%
df = pd.concat([df_advent, df_crime, df_horror, df_mystery, df_sci, df_thriller])
df
# Out:
#                                                 title    year certificate  \
# 0   2.\nThe Lord of the Rings: The Return of the K...  (2003)          PG
# 1                               4.\nInception\n(2010)  (2010)       PG-13
# 2   5.\nThe Lord of the Rings: The Two Towers\n(2002)  (2002)          PG
# 3   6.\nThe Lord of the Rings: The Fellowship of t...  (2001)          PG
# 4                 8.\nThe Empire Strikes Back\n(1980)  (1980)          PG
# ..                                                ...     ...         ...
# 26                         37.\nJurassic Park\n(1993)  (1993)          PG
# 27    38.\nIndiana Jones and the Last Crusade\n(1989)  (1989)           G
# 28          42.\nThe Bridge on the River Kwai\n(1957)  (1957)          PG
# 29     47.\nEverything Everywhere All at Once\n(2022)  (2022)           R
# 30                                 48.\nKlaus\n(2019)  (2019)          PG
#
#        time      genre  rating                      metascore  \
# 0   201 min  adventure     9.0  94        \n        Metascore
# 1   148 min  adventure     8.8  74        \n        Metascore
# 2   179 min  adventure     8.8  87        \n        Metascore
# 3   178 min  adventure     8.8  92        \n        Metascore
# 4   124 min  adventure     8.7  82        \n        Metascore
# ..      ...        ...     ...                            ...
# 26  127 min   thriller     8.2  68        \n        Metascore
# 27  127 min   thriller     8.2  65        \n        Metascore
# 28  161 min   thriller     8.2  87        \n        Metascore
# 29  139 min   thriller     8.1  81        \n        Metascore
# 30   96 min   thriller     8.1  65        \n        Metascore
#
#                                           simple_desc  \
# 0   Gandalf and Aragorn lead the World of Men agai...
# 1   A thief who steals corporate secrets through t...
# 2   While Frodo and Sam edge closer to Mordor with...
# 3   A meek Hobbit from the Shire and eight compani...
# 4   After the Rebels are brutally overpowered by t...
# ..                                                ...
# 26  A pragmatic paleontologist touring an almost c...
# 27  In 1938, after his father Professor Henry Jone...
# 28  British POWs are forced to build a railway bri...
# 29  An aging Chinese immigrant is swept up in an i...
# 30  A simple act of kindness always sparks another...
#
#                                     votes
# 0   Votes:\n1,836,623\n| Gross:\n$377.85M
# 1   Votes:\n2,336,649\n| Gross:\n$292.58M
# 2   Votes:\n1,658,409\n| Gross:\n$342.55M
# 3   Votes:\n1,865,692\n| Gross:\n$315.54M
# 4   Votes:\n1,286,469\n| Gross:\n$290.48M
# ..                                    ...
# 26    Votes:\n985,046\n| Gross:\n$402.45M
# 27    Votes:\n753,018\n| Gross:\n$197.17M
# 28     Votes:\n221,376\n| Gross:\n$44.91M
# 29                        Votes:\n239,452
# 30                        Votes:\n149,295
#
# [186 rows x 9 columns]

# %%
#import re
#df['title'].str.split("\n", 2, expand = True)
df['year'] = df['year'].str.replace('(', '', regex=True)
df['year'] = df['year'].str.replace(')', '', regex=True)
df['year'] = df['year'].str.replace('I 2015', '2015', regex=True)
df['year'] = df['year'].str.replace('I 2017', '2017', regex=True)
df['votes'] = df['votes'].str.replace(',', '', regex=True)
df['metascore'] = df['metascore'].str.replace(' \n', '', regex=True)
df['metascore'] = df['metascore'].str.replace(' Metascore', '', regex=True)
df['time'] = df['time'].str.replace(' min', '', regex=True)
df
# Out:
#                                                 title  year certificate time  \
# 0   2.\nThe Lord of the Rings: The Return of the K...  2003          PG  201
# 1                               4.\nInception\n(2010)  2010       PG-13  148
# 2   5.\nThe Lord of the Rings: The Two Towers\n(2002)  2002          PG  179
# 3   6.\nThe Lord of the Rings: The Fellowship of t...  2001          PG  178
# 4                 8.\nThe Empire Strikes Back\n(1980)  1980          PG  124
# ..                                                ...   ...         ...  ...
# 26                         37.\nJurassic Park\n(1993)  1993          PG  127
# 27    38.\nIndiana Jones and the Last Crusade\n(1989)  1989           G  127
# 28          42.\nThe Bridge on the River Kwai\n(1957)  1957          PG  161
# 29     47.\nEverything Everywhere All at Once\n(2022)  2022           R  139
# 30                                 48.\nKlaus\n(2019)  2019          PG   96
#
#         genre  rating         metascore  \
# 0   adventure     9.0  94
# 1   adventure     8.8  74
# 2   adventure     8.8  87
# 3   adventure     8.8  92
# 4   adventure     8.7  82
# ..        ...     ...               ...
# 26   thriller     8.2  68
# 27   thriller     8.2  65
# 28   thriller     8.2  87
# 29   thriller     8.1  81
# 30   thriller     8.1  65
#
#                                           simple_desc  \
# 0   Gandalf and Aragorn lead the World of Men agai...
# 1   A thief who steals corporate secrets through t...
# 2   While Frodo and Sam edge closer to Mordor with...
# 3   A meek Hobbit from the Shire and eight compani...
# 4   After the Rebels are brutally overpowered by t...
# ..                                                ...
# 26  A pragmatic paleontologist touring an almost c...
# 27  In 1938, after his father Professor Henry Jone...
# 28  British POWs are forced to build a railway bri...
# 29  An aging Chinese immigrant is swept up in an i...
# 30  A simple act of kindness always sparks another...
#
#                                   votes
# 0   Votes:\n1836623\n| Gross:\n$377.85M
# 1   Votes:\n2336649\n| Gross:\n$292.58M
# 2   Votes:\n1658409\n| Gross:\n$342.55M
# 3   Votes:\n1865692\n| Gross:\n$315.54M
# 4   Votes:\n1286469\n| Gross:\n$290.48M
# ..                                  ...
# 26   Votes:\n985046\n| Gross:\n$402.45M
# 27   Votes:\n753018\n| Gross:\n$197.17M
# 28    Votes:\n221376\n| Gross:\n$44.91M
# 29                       Votes:\n239452
# 30                       Votes:\n149295
#
# [186 rows x 9 columns]

# %%
df['num'], df['title'], df['ye'] = df['title'].str.split('\n', 2).str
df['vot'], df['votes'], df['grss'], df['gross'] = df['votes'].str.split('\n', 3).str
df
# Out:
# /tmp/ipykernel_91844/1737250600.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df['num'], df['title'], df['ye'] = df['title'].str.split('\n', 2).str
# /tmp/ipykernel_91844/1737250600.py:2: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df['vot'], df['votes'], df['grss'], df['gross'] = df['votes'].str.split('\n', 3).str
#                                                 title  year certificate time  \
# 0       The Lord of the Rings: The Return of the King  2003          PG  201
# 1                                           Inception  2010       PG-13  148
# 2               The Lord of the Rings: The Two Towers  2002          PG  179
# 3   The Lord of the Rings: The Fellowship of the Ring  2001          PG  178
# 4                             The Empire Strikes Back  1980          PG  124
# ..                                                ...   ...         ...  ...
# 26                                      Jurassic Park  1993          PG  127
# 27                 Indiana Jones and the Last Crusade  1989           G  127
# 28                       The Bridge on the River Kwai  1957          PG  161
# 29                  Everything Everywhere All at Once  2022           R  139
# 30                                              Klaus  2019          PG   96
#
#         genre  rating         metascore  \
# 0   adventure     9.0  94
# 1   adventure     8.8  74
# 2   adventure     8.8  87
# 3   adventure     8.8  92
# 4   adventure     8.7  82
# ..        ...     ...               ...
# 26   thriller     8.2  68
# 27   thriller     8.2  65
# 28   thriller     8.2  87
# 29   thriller     8.1  81
# 30   thriller     8.1  65
#
#                                           simple_desc    votes  num      ye  \
# 0   Gandalf and Aragorn lead the World of Men agai...  1836623   2.  (2003)
# 1   A thief who steals corporate secrets through t...  2336649   4.  (2010)
# 2   While Frodo and Sam edge closer to Mordor with...  1658409   5.  (2002)
# 3   A meek Hobbit from the Shire and eight compani...  1865692   6.  (2001)
# 4   After the Rebels are brutally overpowered by t...  1286469   8.  (1980)
# ..                                                ...      ...  ...     ...
# 26  A pragmatic paleontologist touring an almost c...   985046  37.  (1993)
# 27  In 1938, after his father Professor Henry Jone...   753018  38.  (1989)
# 28  British POWs are forced to build a railway bri...   221376  42.  (1957)
# 29  An aging Chinese immigrant is swept up in an i...   239452  47.  (2022)
# 30  A simple act of kindness always sparks another...   149295  48.  (2019)
#
#        vot      grss     gross
# 0   Votes:  | Gross:  $377.85M
# 1   Votes:  | Gross:  $292.58M
# 2   Votes:  | Gross:  $342.55M
# 3   Votes:  | Gross:  $315.54M
# 4   Votes:  | Gross:  $290.48M
# ..     ...       ...       ...
# 26  Votes:  | Gross:  $402.45M
# 27  Votes:  | Gross:  $197.17M
# 28  Votes:  | Gross:   $44.91M
# 29  Votes:       NaN       NaN
# 30  Votes:       NaN       NaN
#
# [186 rows x 14 columns]

# %%
#df = df.drop(['num', 'ye', 'grss'], axis=1)
df = df[['title', 'year', 'certificate', 'time', 'genre', 'rating', 'metascore', 'simple_desc', 'votes', 'gross']]
df['gross'] = df['gross'].str.replace('$', '', regex=True)
df['gross'] = df['gross'].str.replace('M', '', regex=True)
df['gross'] = df['gross'].fillna(0)
df
# Out:
# /tmp/ipykernel_91844/3540422066.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gross'] = df['gross'].str.replace('$', '', regex=True)
# /tmp/ipykernel_91844/3540422066.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gross'] = df['gross'].str.replace('M', '', regex=True)
# /tmp/ipykernel_91844/3540422066.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gross'] = df['gross'].fillna(0)
#                                                 title  year certificate time  \
# 0       The Lord of the Rings: The Return of the King  2003          PG  201
# 1                                           Inception  2010       PG-13  148
# 2               The Lord of the Rings: The Two Towers  2002          PG  179
# 3   The Lord of the Rings: The Fellowship of the Ring  2001          PG  178
# 4                             The Empire Strikes Back  1980          PG  124
# ..                                                ...   ...         ...  ...
# 26                                      Jurassic Park  1993          PG  127
# 27                 Indiana Jones and the Last Crusade  1989           G  127
# 28                       The Bridge on the River Kwai  1957          PG  161
# 29                  Everything Everywhere All at Once  2022           R  139
# 30                                              Klaus  2019          PG   96
#
#         genre  rating         metascore  \
# 0   adventure     9.0  94
# 1   adventure     8.8  74
# 2   adventure     8.8  87
# 3   adventure     8.8  92
# 4   adventure     8.7  82
# ..        ...     ...               ...
# 26   thriller     8.2  68
# 27   thriller     8.2  65
# 28   thriller     8.2  87
# 29   thriller     8.1  81
# 30   thriller     8.1  65
#
#                                           simple_desc    votes   gross
# 0   Gandalf and Aragorn lead the World of Men agai...  1836623  377.85
# 1   A thief who steals corporate secrets through t...  2336649  292.58
# 2   While Frodo and Sam edge closer to Mordor with...  1658409  342.55
# 3   A meek Hobbit from the Shire and eight compani...  1865692  315.54
# 4   After the Rebels are brutally overpowered by t...  1286469  290.48
# ..                                                ...      ...     ...
# 26  A pragmatic paleontologist touring an almost c...   985046  402.45
# 27  In 1938, after his father Professor Henry Jone...   753018  197.17
# 28  British POWs are forced to build a railway bri...   221376   44.91
# 29  An aging Chinese immigrant is swept up in an i...   239452       0
# 30  A simple act of kindness always sparks another...   149295       0
#
# [186 rows x 10 columns]

# %%
df.rename(columns = {'time':'time(min)', 'simple_desc':'description', 'gross':'gross_earning(M)'}, inplace = True)
df
# Out:
# /tmp/ipykernel_91844/3380135614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'time':'time(min)', 'simple_desc':'description', 'gross':'gross_earning(M)'}, inplace = True)
#                                                 title  year certificate  \
# 0       The Lord of the Rings: The Return of the King  2003          PG
# 1                                           Inception  2010       PG-13
# 2               The Lord of the Rings: The Two Towers  2002          PG
# 3   The Lord of the Rings: The Fellowship of the Ring  2001          PG
# 4                             The Empire Strikes Back  1980          PG
# ..                                                ...   ...         ...
# 26                                      Jurassic Park  1993          PG
# 27                 Indiana Jones and the Last Crusade  1989           G
# 28                       The Bridge on the River Kwai  1957          PG
# 29                  Everything Everywhere All at Once  2022           R
# 30                                              Klaus  2019          PG
#
#    time(min)      genre  rating         metascore  \
# 0        201  adventure     9.0  94
# 1        148  adventure     8.8  74
# 2        179  adventure     8.8  87
# 3        178  adventure     8.8  92
# 4        124  adventure     8.7  82
# ..       ...        ...     ...               ...
# 26       127   thriller     8.2  68
# 27       127   thriller     8.2  65
# 28       161   thriller     8.2  87
# 29       139   thriller     8.1  81
# 30        96   thriller     8.1  65
#
#                                           description    votes  \
# 0   Gandalf and Aragorn lead the World of Men agai...  1836623
# 1   A thief who steals corporate secrets through t...  2336649
# 2   While Frodo and Sam edge closer to Mordor with...  1658409
# 3   A meek Hobbit from the Shire and eight compani...  1865692
# 4   After the Rebels are brutally overpowered by t...  1286469
# ..                                                ...      ...
# 26  A pragmatic paleontologist touring an almost c...   985046
# 27  In 1938, after his father Professor Henry Jone...   753018
# 28  British POWs are forced to build a railway bri...   221376
# 29  An aging Chinese immigrant is swept up in an i...   239452
# 30  A simple act of kindness always sparks another...   149295
#
#    gross_earning(M)
# 0            377.85
# 1            292.58
# 2            342.55
# 3            315.54
# 4            290.48
# ..              ...
# 26           402.45
# 27           197.17
# 28            44.91
# 29                0
# 30                0
#
# [186 rows x 10 columns]

# %%
#df['year'].unique()

# %%
df['title'] = df['title'].astype(str)
df['year'] = df['year'].astype(int)
df['certificate'] = df['certificate'].astype(str)
df['time(min)'] = df['time(min)'].astype(int)
df['genre'] = df['genre'].astype(str)
df['rating'] = df['rating'].astype(float)
df['metascore'] = df['metascore'].astype(int)
df['description'] = df['description'].astype(str)
df['votes'] = df['votes'].astype(int)
df['gross_earning(M)'] = df['gross_earning(M)'].astype(float)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 0 to 30
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             186 non-null    object
#  1   year              186 non-null    int64
#  2   certificate       186 non-null    object
#  3   time(min)         186 non-null    int64
#  4   genre             186 non-null    object
#  5   rating            186 non-null    float64
#  6   metascore         186 non-null    int64
#  7   description       186 non-null    object
#  8   votes             186 non-null    int64
#  9   gross_earning(M)  186 non-null    float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 16.0+ KB
# /tmp/ipykernel_91844/1017861569.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['title'] = df['title'].astype(str)
# /tmp/ipykernel_91844/1017861569.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['year'].astype(int)
# /tmp/ipykernel_91844/1017861569.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['certificate'] = df['certificate'].astype(str)
# /tmp/ipykernel_91844/1017861569.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['time(min)'] = df['time(min)'].astype(int)
# /tmp/ipykernel_91844/1017861569.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genre'] = df['genre'].astype(str)
# /tmp/ipykernel_91844/1017861569.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].astype(float)
# /tmp/ipykernel_91844/1017861569.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['metascore'] = df['metascore'].astype(int)
# /tmp/ipykernel_91844/1017861569.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['description'] = df['description'].astype(str)
# /tmp/ipykernel_91844/1017861569.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['votes'] = df['votes'].astype(int)
# /tmp/ipykernel_91844/1017861569.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gross_earning(M)'] = df['gross_earning(M)'].astype(float)

# %%
df.to_csv('clean-movie-review.csv', index=False)

# %% [markdown]
# ## Load

# %% [markdown]
# ## Load to s3, Redshift, DynamoDB

# %%
import boto3
AWS_KEY_ID='###'  
AWS_SECRET='###'
# instantiate an s3 object using boto3
s3 = boto3.client('s3', region_name = 'us-east-1',\
                  aws_access_key_id = AWS_KEY_ID, aws_secret_access_key = AWS_SECRET)

# %%
# create a bucket
bucket = s3.create_bucket(Bucket = 'movie-review-2022')

# %%
import os
path = 'rawfile/'
for root, dirs, files in os.walk(path):
    for name in files:
        if name.endswith(".csv"):
            s3.upload_file(Filename = name, Bucket = 'movie-review-2022', Key = 'raw/'+name)

# %%
s3.upload_file(Filename = 'clean-movie-review.csv', Bucket = 'movie-review-2022', Key = 'cleaned/clean-movie-review.csv')

# %%
### Redshift configuration
### username = awsuser
### password = #########2020=Ab
